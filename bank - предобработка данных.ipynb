# %% [markdown]
# # Исследование надёжности заёмщиков
#
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели **кредитного скоринга** — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию

# %%
import pandas as pd
import numpy as np
from pymystem3 import Mystem
from collections import Counter
df = pd.read_csv('/datasets/data.csv') 
#display(df.tail(10)) # смотрим хвост
display(df.head(10)) # смотрим голову
#df.info # получаем общую информацию по таблице
#print(df.columns) # проверяем заголовки столбцов
#print(df.isna().sum()) # проверяем количество пропуском и где они 
#print(df.isnull().sum()) # также проверяем количество пропуском и где они
#print(df['dob_years'].min()) смотрим минимальный возраст клиента
#print(df['dob_years'].max()) смотрим максимальный возраст клиента
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
# 5         0    -926.185831         27    высшее             0
# 6         0   -2879.202052         43    высшее             0
# 7         0    -152.779569         50   СРЕДНЕЕ             1
# 8         2   -6929.865299         35    ВЫСШЕЕ             0
# 9         0   -2188.756445         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
# 5  гражданский брак                 1      M   компаньон     0  255763.565419
# 6   женат / замужем                 0      F   компаньон     0  240525.971920
# 7   женат / замужем                 0      M   сотрудник     0  135823.934197
# 8  гражданский брак                 1      F   сотрудник     0   95856.832424
# 9   женат / замужем                 0      M   сотрудник     0  144425.938277
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу
# 5               покупка жилья
# 6           операции с жильем
# 7                 образование
# 8       на проведение свадьбы
# 9     покупка жилья для семьи

# %% [markdown]
# **Вывод**

# %% [markdown]
# Обнаруженные проблемы:
# - в столбце education есть как строчные так и заглавные значения
# - отрицательные значения в днях стажа
# - одинаковое количество пропусков в days_employed и total_income
# - в столбцах days_employed и total_income данные типо float, а должны быть int, поскольку маловероятно есть необходимость указывать в данных столбцах данные до ста тысячных долей
# - минимальный значение в возрасте клиента = 0
# - неизвестна валюта ежемесячного дохода

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %%
df.sort_values(by = 'days_employed', ascending = False).tail(20)
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 21308         0            NaN         48              среднее             1
# 21311         0            NaN         49              среднее             1
# 21321         0            NaN         56              Среднее             1
# 21350         0            NaN         21              среднее             1
# 21364         0            NaN         50              среднее             1
# 21369         2            NaN         42              среднее             1
# 21390        20            NaN         53              среднее             1
# 21391         0            NaN         52              среднее             1
# 21407         1            NaN         36              среднее             1
# 21414         0            NaN         65              среднее             1
# 21415         0            NaN         54              среднее             1
# 21423         0            NaN         63              среднее             1
# 21426         0            NaN         49              среднее             1
# 21432         1            NaN         38  неоконченное высшее             2
# 21463         1            NaN         35               высшее             0
# 21489         2            NaN         47              Среднее             1
# 21495         1            NaN         50              среднее             1
# 21497         0            NaN         48               ВЫСШЕЕ             0
# 21502         1            NaN         42              среднее             1
# 21510         2            NaN         28              среднее             1
#
#                family_status  family_status_id gender income_type  debt  \
# 21308        женат / замужем                 0      F   компаньон     0
# 21311        женат / замужем                 0      F   пенсионер     0
# 21321        женат / замужем                 0      F   пенсионер     0
# 21350  Не женат / не замужем                 4      M   компаньон     0
# 21364        женат / замужем                 0      M   сотрудник     0
# 21369              в разводе                 3      M   компаньон     0
# 21390        женат / замужем                 0      M   компаньон     0
# 21391        женат / замужем                 0      F   компаньон     0
# 21407        женат / замужем                 0      F   компаньон     0
# 21414        женат / замужем                 0      F   пенсионер     0
# 21415        женат / замужем                 0      F   пенсионер     0
# 21423        женат / замужем                 0      M   пенсионер     0
# 21426        женат / замужем                 0      F   сотрудник     1
# 21432  Не женат / не замужем                 4      F   сотрудник     0
# 21463       гражданский брак                 1      M   сотрудник     0
# 21489        женат / замужем                 0      M   компаньон     0
# 21495       гражданский брак                 1      F   сотрудник     0
# 21497        женат / замужем                 0      F   компаньон     0
# 21502        женат / замужем                 0      F   сотрудник     0
# 21510        женат / замужем                 0      F   сотрудник     0
#
#        total_income                           purpose
# 21308           NaN           покупка жилья для сдачи
# 21311           NaN           покупка жилья для сдачи
# 21321           NaN          операции с недвижимостью
# 21350           NaN             на покупку автомобиля
# 21364           NaN   операции со своей недвижимостью
# 21369           NaN        покупка жилой недвижимости
# 21390           NaN        покупка жилой недвижимости
# 21391           NaN           покупка жилья для семьи
# 21407           NaN  строительство жилой недвижимости
# 21414           NaN              покупка своего жилья
# 21415           NaN                 операции с жильем
# 21423           NaN              сделка с автомобилем
# 21426           NaN                      недвижимость
# 21432           NaN                 операции с жильем
# 21463           NaN             на проведение свадьбы
# 21489           NaN              сделка с автомобилем
# 21495           NaN                           свадьба
# 21497           NaN        строительство недвижимости
# 21502           NaN  строительство жилой недвижимости
# 21510           NaN           приобретение автомобиля

# %% [markdown]
# **Вывод**

# %% [markdown]
# одинаковое количество пропусков в days_employed и total_income, поскольку люди в этих столбцах старше 18 лет, маловероятно, что все они нигде не работали и не получали никакого дохода, следовательно скорей всего тут присутствует ошибка ввода данных.
# заменим пропуски на нули, поскольку замена значений на медианные может повысить вероятность получения кредита.

# %% [markdown]
# Также обнаружены отрицательные значения в столбце days_employed- общий трудовой стаж, скорее всего ошибка внесения , преобразуем их в положительные

# %%
df['days_employed'] = df['days_employed'].apply(abs)

# %%
print(df['days_employed'].median())
print(df['total_income'].median())
# Out:
# 2194.220566878695
# 145017.93753253992

# %% [markdown]
# также проверим максимальный трудовой стаж

# %%
df.sort_values(by = 'days_employed', ascending = False).head(15) #  сортируем столбец по убыванию
# Out:
#        children  days_employed  dob_years education  education_id  \
# 6954          0  401755.400475         56   среднее             1
# 10006         0  401715.811749         69    высшее             0
# 7664          1  401675.093434         61   среднее             1
# 2156          0  401674.466633         60   среднее             1
# 7794          0  401663.850046         61   среднее             1
# 4697          0  401635.032697         56   среднее             1
# 13420         0  401619.633298         63   Среднее             1
# 17823         0  401614.475622         59   среднее             1
# 10991         0  401591.828457         56   среднее             1
# 8369          0  401590.452231         58   среднее             1
# 1184          0  401575.196728         55   среднее             1
# 4949          0  401573.905288         54   среднее             1
# 15192         0  401556.753550         68    Высшее             0
# 5716          0  401524.259153         57   среднее             1
# 10484         0  401517.276388         68   среднее             1
#
#                family_status  family_status_id gender income_type  debt  \
# 6954          вдовец / вдова                 2      F   пенсионер     0
# 10006  Не женат / не замужем                 4      F   пенсионер     0
# 7664         женат / замужем                 0      F   пенсионер     0
# 2156         женат / замужем                 0      M   пенсионер     0
# 7794        гражданский брак                 1      F   пенсионер     0
# 4697         женат / замужем                 0      F   пенсионер     0
# 13420       гражданский брак                 1      F   пенсионер     0
# 17823        женат / замужем                 0      F   пенсионер     0
# 10991              в разводе                 3      F   пенсионер     0
# 8369         женат / замужем                 0      F   пенсионер     0
# 1184        гражданский брак                 1      M   пенсионер     0
# 4949         женат / замужем                 0      F   пенсионер     0
# 15192       гражданский брак                 1      F   пенсионер     0
# 5716          вдовец / вдова                 2      F   пенсионер     0
# 10484        женат / замужем                 0      F   пенсионер     0
#
#         total_income                                purpose
# 6954   176278.441171                           ремонт жилью
# 10006   57390.256908                  получение образования
# 7664   126214.519212                      операции с жильем
# 2156   325395.724541                             автомобили
# 7794    48286.441362                                свадьба
# 4697    48242.322502                   покупка недвижимости
# 13420   51449.788325                        сыграть свадьбу
# 17823  152769.694536                покупка жилья для сдачи
# 10991   39513.517543  получение дополнительного образования
# 8369   175306.312902                            образование
# 1184    29749.813177                  на проведение свадьбы
# 4949    52927.428675      покупка коммерческой недвижимости
# 15192  231820.611741                                свадьба
# 5716   143342.778458                приобретение автомобиля
# 10484  304295.888626                      операции с жильем

# %% [markdown]
# присутствие в данных стажа в тысячу лет, выглядит подозрительно, возможно присутствует ошибка в записи данных

# %%
df.loc[df['days_employed'] > 25550, 'days_employed'] = df['days_employed'].median()
df.sort_values(by = 'days_employed', ascending = False).head(15)
display(df.head())
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   Среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0    2194.220567         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу

# %%
df['days_employed'] = df['days_employed'].fillna(df['days_employed'].median()) # заменяем пропущенные значения в столбце days_employed(отработанные дни)
# на 0
#df['total_income'] = df['total_income'].fillna(df['total_income'].median()) # заменяем пропущенные значения в столбце total_income — ежемесячный доход
# на 0
print(df.isnull().sum()) # проверяем смотрим количество пропушенных значений и где они находятся
# print(df.info()) # еще раз проверяеv
# Out:
# children               0
# days_employed          0
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %%
display(df['income_type'].value_counts())
# Out:
# сотрудник          11119
# компаньон           5085
# пенсионер           3856
# госслужащий         1459
# предприниматель        2
# безработный            2
# студент                1
# в декрете              1
# Name: income_type, dtype: int64

# %%
#display('пенсионер',df.loc[df['income_type'] == 'пенсионер', 'total_income'].median())
#display('сотрудник',df.loc[df['income_type'] == 'сотрудник', 'total_income'].median())

for _type in df['income_type'].unique():
    median = df.loc[df['income_type'] == _type, 'total_income'].median()
    print('Медианная зарплата {} {:.2f}'.format(_type, median))
    df.loc[(df['total_income'].isna()) & (df['income_type'] == _type), 'total_income'] = median
# Out:
# Медианная зарплата сотрудник 142594.40
# Медианная зарплата пенсионер 118514.49
# Медианная зарплата компаньон 172357.95
# Медианная зарплата госслужащий 150447.94
# Медианная зарплата безработный 131339.75
# Медианная зарплата предприниматель 499163.14
# Медианная зарплата студент 98201.63
# Медианная зарплата в декрете 53829.13

# %%
#df.sort_values(by = 'days_employed', ascending = False).tail(15)
df.sort_values(by = 'total_income', ascending = False).tail(10) 
display(df.head())
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   Среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0    2194.220567         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу

# %%
# найдем самого возрастного человека и предположим, что он работает с 18 лет
max_days_of_employment = (df['dob_years'].max() - 18) * 365
max_days_of_employment # Получим количество дней, по которым можно сделать отсев
# Out:
# 20805

# %%
df[df['days_employed'] > max_days_of_employment]['days_employed'].count() / 20805 * 100 # Многовато, почти 16.5% от всего набора
#переведем данные в года и добавим новый столбец
# Out:
# 0.0

# %%
df['years_employed'] = df['days_employed'] / 365

# %%
df['years_employed'] = df['years_employed'].astype(int)

# %%
del df['days_employed']# удалим столбец с днями и оставим только с года, работующий по тысяче лет отложим до лемматизации

# %%
df['children'].unique() # проверим столбец с детьми
# Out:
# array([ 1,  0,  3,  2, -1,  4, 20,  5])

# %%
# присутствуют необычные значение: -1 и 20, проверим сколько строк с -1
df[df['children'] == -1]['children'].count()
# Out:
# 47

# %%
df['children'] = df['children'].replace(-1, 1) # проведем замену -1 на 1
df[df['children'] == -1]['children'].count() # проверим замену
# Out:
# 0

# %%
df[df['children'] == 20]['children'].count()# проверим сколько строк с 20 детьми
# Out:
# 76

# %%
df['children'].value_counts()# посмотрим соотношение этих строк к остальным знаениям
# Out:
# 0     14149
# 1      4865
# 2      2055
# 3       330
# 20       76
# 4        41
# 5         9
# Name: children, dtype: int64

# %%
# значение сильно выделяется из общих показателей, следовательно скорей всего ошибка в записи, поменяем 20 на 2
df['children'] = df['children'].replace(20, 2)
df['children'].unique()# проверяем замену
# Out:
# array([1, 0, 3, 2, 4, 5])

# %%
df['dob_years'].describe() # проверим возраст
# Out:
# count    21525.000000
# mean        43.293380
# std         12.574584
# min          0.000000
# 25%         33.000000
# 50%         42.000000
# 75%         53.000000
# max         75.000000
# Name: dob_years, dtype: float64

# %%
df['dob_years'].value_counts()#проверия количество людей младше 18 лет, таких 101 значение в категории 0
# Out:
# 35    617
# 40    609
# 41    607
# 34    603
# 38    598
# 42    597
# 33    581
# 39    573
# 31    560
# 36    555
# 44    547
# 29    545
# 30    540
# 48    538
# 37    537
# 50    514
# 43    513
# 32    510
# 49    508
# 28    503
# 45    497
# 27    493
# 56    487
# 52    484
# 47    480
# 54    479
# 46    475
# 58    461
# 57    460
# 53    459
# 51    448
# 59    444
# 55    443
# 26    408
# 60    377
# 25    357
# 61    355
# 62    352
# 63    269
# 64    265
# 24    264
# 23    254
# 65    194
# 66    183
# 22    183
# 67    167
# 21    111
# 0     101
# 68     99
# 69     85
# 70     65
# 71     58
# 20     51
# 72     33
# 19     14
# 73      8
# 74      6
# 75      1
# Name: dob_years, dtype: int64

# %%
df[df['years_employed'] > 70].groupby(['dob_years'])['dob_years'].count()
# Out:
# Series([], Name: dob_years, dtype: int64)

# %% [markdown]
# **Вывод**

# %% [markdown]
# Заменили пропущенные данные столбцов days_employed — общий трудовой стаж в днях и total_income — ежемесячный доход на 0, заменили стаж с дней на года и исправили неправильно записанное количество детей

# %% [markdown]
# ### Замена типа данных

# %%
df['years_employed'] = df['years_employed'].astype(int) # меняем в столбце df['years_employed'] 
#вещественый тип float64 на int64
df['total_income'] = df['total_income'].astype(int) # меняем в столбце data['df_employed']
print(df.info())
#df[df.duplicated(keep = False)].sort_values(by = data.columns.values.tolist())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        21525 non-null int64
# purpose             21525 non-null object
# years_employed      21525 non-null int64
# dtypes: int64(7), object(5)
# memory usage: 2.0+ MB
# None

# %% [markdown]
# **Вывод**

# %% [markdown]
# В столбцах years_employed и total_income содержаться данные вещественного типа (float), а должны быть целочисленные тк врядли зарплата указывается до ста тысячных долей рубля и отработанные дни тоже использован метод astype

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# Как мы уже заметили в столбцах 'education' и 'family_status' гуляет регистр, приведем его к нижнему регистру

# %%
df['education'] = df['education'].str.lower()
df['family_status'] = df['family_status'].str.lower()

# %%
display(df['education'].value_counts())
print('__________________________________')
display(df['family_status'].value_counts())#проверия изменения
# Out:
# среднее                15233
# высшее                  5260
# неоконченное высшее      744
# начальное                282
# ученая степень             6
# Name: education, dtype: int64
# __________________________________
# женат / замужем          12380
# гражданский брак          4177
# не женат / не замужем     2813
# в разводе                 1195
# вдовец / вдова             960
# Name: family_status, dtype: int64

# %%
df.duplicated().sum() # проверим наличие дублей
# Out:
# 71

# %%
df = df.drop_duplicates().reset_index(drop=True) # Удалим дубли и сбросим индекс
df.duplicated().sum() # Проверим удалились ли дубли
# Out:
# 0

# %% [markdown]
# **Вывод**

# %% [markdown]
# Нашли дубликаты и удалили их

# %% [markdown]
# ### Лемматизация

# %%
#импортируем библиотеки
m = Mystem()
lemmas = m.lemmatize(df['purpose'][3])
print(lemmas)
print(len(df['purpose']))
# Out:
# ['дополнительный', ' ', 'образование', '\n']
# 21454

# %%
uniq_purpose = df['purpose'].unique()
print(uniq_purpose) #берем только уникальные значения
# Out:
# ['покупка жилья' 'приобретение автомобиля' 'дополнительное образование'
#  'сыграть свадьбу' 'операции с жильем' 'образование'
#  'на проведение свадьбы' 'покупка жилья для семьи' 'покупка недвижимости'
#  'покупка коммерческой недвижимости' 'покупка жилой недвижимости'
#  'строительство собственной недвижимости' 'недвижимость'
#  'строительство недвижимости' 'на покупку подержанного автомобиля'
#  'на покупку своего автомобиля' 'операции с коммерческой недвижимостью'
#  'строительство жилой недвижимости' 'жилье'
#  'операции со своей недвижимостью' 'автомобили' 'заняться образованием'
#  'сделка с подержанным автомобилем' 'получение образования' 'автомобиль'
#  'свадьба' 'получение дополнительного образования' 'покупка своего жилья'
#  'операции с недвижимостью' 'получение высшего образования'
#  'свой автомобиль' 'сделка с автомобилем' 'профильное образование'
#  'высшее образование' 'покупка жилья для сдачи' 'на покупку автомобиля'
#  'ремонт жилью' 'заняться высшим образованием']

# %%
uniq_purpose = uniq_purpose.tolist()
print(uniq_purpose) #преобразуем массив в питоновский лист
# Out:
# ['покупка жилья', 'приобретение автомобиля', 'дополнительное образование', 'сыграть свадьбу', 'операции с жильем', 'образование', 'на проведение свадьбы', 'покупка жилья для семьи', 'покупка недвижимости', 'покупка коммерческой недвижимости', 'покупка жилой недвижимости', 'строительство собственной недвижимости', 'недвижимость', 'строительство недвижимости', 'на покупку подержанного автомобиля', 'на покупку своего автомобиля', 'операции с коммерческой недвижимостью', 'строительство жилой недвижимости', 'жилье', 'операции со своей недвижимостью', 'автомобили', 'заняться образованием', 'сделка с подержанным автомобилем', 'получение образования', 'автомобиль', 'свадьба', 'получение дополнительного образования', 'покупка своего жилья', 'операции с недвижимостью', 'получение высшего образования', 'свой автомобиль', 'сделка с автомобилем', 'профильное образование', 'высшее образование', 'покупка жилья для сдачи', 'на покупку автомобиля', 'ремонт жилью', 'заняться высшим образованием']

# %%
uniq_purpose_lemm = []
for i in uniq_purpose:
    uniq_purpose_lemm.extend(m.lemmatize(i))
    print(uniq_purpose_lemm) #Функция для Лемматизации элементов
# Out:
# ['покупка', ' ', 'жилье', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n', 'получение', ' ', 'дополнительный', ' ', 'образование', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n', 'получение', ' ', 'дополнительный', ' ', 'образование', '\n', 'покупка', ' ', 'свой', ' ', 'жилье', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n', 'получение', ' ', 'дополнительный', ' ', 'образование', '\n', 'покупка', ' ', 'свой', ' ', 'жилье', '\n', 'операция', ' ', 'с', ' ', 'недвижимость', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n', 'получение', ' ', 'дополнительный', ' ', 'образование', '\n', 'покупка', ' ', 'свой', ' ', 'жилье', '\n', 'операция', ' ', 'с', ' ', 'недвижимость', '\n', 'получение', ' ', 'высокий', ' ', 'образование', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n', 'получение', ' ', 'дополнительный', ' ', 'образование', '\n', 'покупка', ' ', 'свой', ' ', 'жилье', '\n', 'операция', ' ', 'с', ' ', 'недвижимость', '\n', 'получение', ' ', 'высокий', ' ', 'образование', '\n', 'свой', ' ', 'автомобиль', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n', 'получение', ' ', 'дополнительный', ' ', 'образование', '\n', 'покупка', ' ', 'свой', ' ', 'жилье', '\n', 'операция', ' ', 'с', ' ', 'недвижимость', '\n', 'получение', ' ', 'высокий', ' ', 'образование', '\n', 'свой', ' ', 'автомобиль', '\n', 'сделка', ' ', 'с', ' ', 'автомобиль', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n', 'получение', ' ', 'дополнительный', ' ', 'образование', '\n', 'покупка', ' ', 'свой', ' ', 'жилье', '\n', 'операция', ' ', 'с', ' ', 'недвижимость', '\n', 'получение', ' ', 'высокий', ' ', 'образование', '\n', 'свой', ' ', 'автомобиль', '\n', 'сделка', ' ', 'с', ' ', 'автомобиль', '\n', 'профильный', ' ', 'образование', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n', 'получение', ' ', 'дополнительный', ' ', 'образование', '\n', 'покупка', ' ', 'свой', ' ', 'жилье', '\n', 'операция', ' ', 'с', ' ', 'недвижимость', '\n', 'получение', ' ', 'высокий', ' ', 'образование', '\n', 'свой', ' ', 'автомобиль', '\n', 'сделка', ' ', 'с', ' ', 'автомобиль', '\n', 'профильный', ' ', 'образование', '\n', 'высокий', ' ', 'образование', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n', 'получение', ' ', 'дополнительный', ' ', 'образование', '\n', 'покупка', ' ', 'свой', ' ', 'жилье', '\n', 'операция', ' ', 'с', ' ', 'недвижимость', '\n', 'получение', ' ', 'высокий', ' ', 'образование', '\n', 'свой', ' ', 'автомобиль', '\n', 'сделка', ' ', 'с', ' ', 'автомобиль', '\n', 'профильный', ' ', 'образование', '\n', 'высокий', ' ', 'образование', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'сдача', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n', 'получение', ' ', 'дополнительный', ' ', 'образование', '\n', 'покупка', ' ', 'свой', ' ', 'жилье', '\n', 'операция', ' ', 'с', ' ', 'недвижимость', '\n', 'получение', ' ', 'высокий', ' ', 'образование', '\n', 'свой', ' ', 'автомобиль', '\n', 'сделка', ' ', 'с', ' ', 'автомобиль', '\n', 'профильный', ' ', 'образование', '\n', 'высокий', ' ', 'образование', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'сдача', '\n', 'на', ' ', 'покупка', ' ', 'автомобиль', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n', 'получение', ' ', 'дополнительный', ' ', 'образование', '\n', 'покупка', ' ', 'свой', ' ', 'жилье', '\n', 'операция', ' ', 'с', ' ', 'недвижимость', '\n', 'получение', ' ', 'высокий', ' ', 'образование', '\n', 'свой', ' ', 'автомобиль', '\n', 'сделка', ' ', 'с', ' ', 'автомобиль', '\n', 'профильный', ' ', 'образование', '\n', 'высокий', ' ', 'образование', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'сдача', '\n', 'на', ' ', 'покупка', ' ', 'автомобиль', '\n', 'ремонт', ' ', 'жилье', '\n']
# ['покупка', ' ', 'жилье', '\n', 'приобретение', ' ', 'автомобиль', '\n', 'дополнительный', ' ', 'образование', '\n', 'сыграть', ' ', 'свадьба', '\n', 'операция', ' ', 'с', ' ', 'жилье', '\n', 'образование', '\n', 'на', ' ', 'проведение', ' ', 'свадьба', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'семья', '\n', 'покупка', ' ', 'недвижимость', '\n', 'покупка', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'покупка', ' ', 'жилой', ' ', 'недвижимость', '\n', 'строительство', ' ', 'собственный', ' ', 'недвижимость', '\n', 'недвижимость', '\n', 'строительство', ' ', 'недвижимость', '\n', 'на', ' ', 'покупка', ' ', 'подержать', ' ', 'автомобиль', '\n', 'на', ' ', 'покупка', ' ', 'свой', ' ', 'автомобиль', '\n', 'операция', ' ', 'с', ' ', 'коммерческий', ' ', 'недвижимость', '\n', 'строительство', ' ', 'жилой', ' ', 'недвижимость', '\n', 'жилье', '\n', 'операция', ' ', 'со', ' ', 'свой', ' ', 'недвижимость', '\n', 'автомобиль', '\n', 'заниматься', ' ', 'образование', '\n', 'сделка', ' ', 'с', ' ', 'подержанный', ' ', 'автомобиль', '\n', 'получение', ' ', 'образование', '\n', 'автомобиль', '\n', 'свадьба', '\n', 'получение', ' ', 'дополнительный', ' ', 'образование', '\n', 'покупка', ' ', 'свой', ' ', 'жилье', '\n', 'операция', ' ', 'с', ' ', 'недвижимость', '\n', 'получение', ' ', 'высокий', ' ', 'образование', '\n', 'свой', ' ', 'автомобиль', '\n', 'сделка', ' ', 'с', ' ', 'автомобиль', '\n', 'профильный', ' ', 'образование', '\n', 'высокий', ' ', 'образование', '\n', 'покупка', ' ', 'жилье', ' ', 'для', ' ', 'сдача', '\n', 'на', ' ', 'покупка', ' ', 'автомобиль', '\n', 'ремонт', ' ', 'жилье', '\n', 'заниматься', ' ', 'высокий', ' ', 'образование', '\n']

# %%
print(Counter(uniq_purpose_lemm)) # подсчитываем количество упоминаний в тексте
# Out:
# Counter({' ': 59, '\n': 38, 'покупка': 10, 'недвижимость': 10, 'автомобиль': 9, 'образование': 9, 'жилье': 7, 'с': 5, 'операция': 4, 'на': 4, 'свой': 4, 'свадьба': 3, 'строительство': 3, 'получение': 3, 'высокий': 3, 'дополнительный': 2, 'для': 2, 'коммерческий': 2, 'жилой': 2, 'заниматься': 2, 'сделка': 2, 'приобретение': 1, 'сыграть': 1, 'проведение': 1, 'семья': 1, 'собственный': 1, 'подержать': 1, 'со': 1, 'подержанный': 1, 'профильный': 1, 'сдача': 1, 'ремонт': 1})

# %% [markdown]
# чаще всего встречается: образование, недвижимость, автомобиль, жилье, свадьба

# %%
def lemm_purpose(row):
    if 'недвижимость' in m.lemmatize(row):
        return 'недвижимость'
           
    if 'автомобиль' in m.lemmatize(row):
        return 'автомобиль'
            
    if 'жилье' in m.lemmatize(row):
        return 'жилье'
            
    if 'свадьба' in m.lemmatize(row):
        return 'свадьба'
    
    if 'образование' in m.lemmatize(row):
        return 'образование'
             
    else: return 'другое'

# %%
df['purpose'] = df['purpose'].apply(lemm_purpose)
display(df.head()) # применяем к столбцу data['purpose'] и проверяем
# Out:
#    children  dob_years education  education_id     family_status  \
# 0         1         42    высшее             0   женат / замужем
# 1         1         36   среднее             1   женат / замужем
# 2         0         33   среднее             1   женат / замужем
# 3         3         32   среднее             1   женат / замужем
# 4         0         53   среднее             1  гражданский брак
#
#    family_status_id gender income_type  debt  total_income      purpose  \
# 0                 0      F   сотрудник     0        253875        жилье
# 1                 0      F   сотрудник     0        112080   автомобиль
# 2                 0      M   сотрудник     0        145885        жилье
# 3                 0      M   сотрудник     0        267628  образование
# 4                 1      F   пенсионер     0        158616      свадьба
#
#    years_employed
# 0              23
# 1              11
# 2              15
# 3              11
# 4               6

# %% [markdown]
# **Вывод**

# %% [markdown]
# Данные столбца data['purpose'] лемматизированы, цели для удобства сортировки отражены одним словом

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# Делаем сводную таблицу: влияние количество детей клиента на факт погашения кредита
# Bстроим строку с процентами кто имел задолжность количество детей клиента факт погашения кредита

# %%
df_child = df.pivot_table(index = ['children'], values = 'debt', aggfunc = [sum, 'count'])
#df_child = df.groupby(['children',]).agg({'debt':'sum','children':'count'})
df_child['%_total_debt'] = (df_child ['sum','debt']/df_child ['count','debt'])
#df_child.columns = ['Кол-во невозвратов','Кол-во заемщиков','% невозврата']
df_child.style.format({'% невозврата':'{:.2%}'})
#print(df_child)
# Out:
# <style  type="text/css" >
# </style><table id="T_b5a2a724_8a40_11ec_b48a_02420a390fde" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sum</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >%_total_debt</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >debt</th>        <th class="col_heading level1 col1" >debt</th>        <th class="col_heading level1 col2" ></th>    </tr>    <tr>        <th class="index_name level0" >children</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5a2a724_8a40_11ec_b48a_02420a390fdelevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow0_col0" class="data row0 col0" >1063</td>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow0_col1" class="data row0 col1" >14091</td>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow0_col2" class="data row0 col2" >0.0754382</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a2a724_8a40_11ec_b48a_02420a390fdelevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow1_col0" class="data row1 col0" >445</td>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow1_col1" class="data row1 col1" >4855</td>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow1_col2" class="data row1 col2" >0.0916581</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a2a724_8a40_11ec_b48a_02420a390fdelevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow2_col0" class="data row2 col0" >202</td>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow2_col1" class="data row2 col1" >2128</td>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow2_col2" class="data row2 col2" >0.0949248</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a2a724_8a40_11ec_b48a_02420a390fdelevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow3_col0" class="data row3 col0" >27</td>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow3_col1" class="data row3 col1" >330</td>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow3_col2" class="data row3 col2" >0.0818182</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a2a724_8a40_11ec_b48a_02420a390fdelevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow4_col0" class="data row4 col0" >4</td>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow4_col1" class="data row4 col1" >41</td>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow4_col2" class="data row4 col2" >0.097561</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a2a724_8a40_11ec_b48a_02420a390fdelevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow5_col1" class="data row5 col1" >9</td>
#                         <td id="T_b5a2a724_8a40_11ec_b48a_02420a390fderow5_col2" class="data row5 col2" >0</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Делаем сводную таблицу *семейное положение * - факт погашения кредита Bстроим строку с процентами кто имел задолжность *семейное положение * - факт погашения кредита

# %%
df_family = df.groupby('family_status').agg({'debt':'sum', 'family_status':'count'})
df_family['%_total_debt'] = (df_family['debt']/df_family['family_status'])
df_family.columns = ['Кол-во невозвратов','Кол-во заемщиков','% невозврата']
df_family.style.format({'% невозврата':'{:.2%}'})
#print(df_family)
# Out:
# <style  type="text/css" >
# </style><table id="T_b5a5ff78_8a40_11ec_b48a_02420a390fde" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Кол-во невозвратов</th>        <th class="col_heading level0 col1" >Кол-во заемщиков</th>        <th class="col_heading level0 col2" >% невозврата</th>    </tr>    <tr>        <th class="index_name level0" >family_status</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5a5ff78_8a40_11ec_b48a_02420a390fdelevel0_row0" class="row_heading level0 row0" >в разводе</th>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow0_col0" class="data row0 col0" >85</td>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow0_col1" class="data row0 col1" >1195</td>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow0_col2" class="data row0 col2" >7.11%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a5ff78_8a40_11ec_b48a_02420a390fdelevel0_row1" class="row_heading level0 row1" >вдовец / вдова</th>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow1_col0" class="data row1 col0" >63</td>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow1_col1" class="data row1 col1" >959</td>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow1_col2" class="data row1 col2" >6.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a5ff78_8a40_11ec_b48a_02420a390fdelevel0_row2" class="row_heading level0 row2" >гражданский брак</th>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow2_col0" class="data row2 col0" >388</td>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow2_col1" class="data row2 col1" >4151</td>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow2_col2" class="data row2 col2" >9.35%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a5ff78_8a40_11ec_b48a_02420a390fdelevel0_row3" class="row_heading level0 row3" >женат / замужем</th>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow3_col0" class="data row3 col0" >931</td>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow3_col1" class="data row3 col1" >12339</td>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow3_col2" class="data row3 col2" >7.55%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5a5ff78_8a40_11ec_b48a_02420a390fdelevel0_row4" class="row_heading level0 row4" >не женат / не замужем</th>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow4_col0" class="data row4 col0" >274</td>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow4_col1" class="data row4 col1" >2810</td>
#                         <td id="T_b5a5ff78_8a40_11ec_b48a_02420a390fderow4_col2" class="data row4 col2" >9.75%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Сделаем общую сводную таблицу c процентами

# %%
df_child_family = df.groupby(['children', 'family_status']).agg({'debt':'sum', 'family_status':'count'})
df_child_family['%_total_debt'] = (df_child_family['debt']/df_child_family['family_status'])*100
df_child_family.columns = ['Кол. невозвр','Кол-во заемщиков','% невозврата']
#df_child_family.format({'Процент невозврата':'{:.2%}'})
display(df_child_family)
# Out:
#                                 Кол. невозвр  Кол-во заемщиков  % невозврата
# children family_status
# 0        в разводе                        55               784      7.015306
#          вдовец / вдова                   53               847      6.257379
#          гражданский брак                229              2730      8.388278
#          женат / замужем                 516              7468      6.909480
#          не женат / не замужем           210              2262      9.283820
# 1        в разводе                        21               316      6.645570
#          вдовец / вдова                    7                81      8.641975
#          гражданский брак                118              1000     11.800000
#          женат / замужем                 247              3004      8.222370
#          не женат / не замужем            52               454     11.453744
# 2        в разводе                         8                83      9.638554
#          вдовец / вдова                    3                24     12.500000
#          гражданский брак                 33               355      9.295775
#          женат / замужем                 148              1582      9.355247
#          не женат / не замужем            10                84     11.904762
# 3        в разводе                         1                11      9.090909
#          вдовец / вдова                    0                 6      0.000000
#          гражданский брак                  8                56     14.285714
#          женат / замужем                  17               249      6.827309
#          не женат / не замужем             1                 8     12.500000
# 4        в разводе                         0                 1      0.000000
#          вдовец / вдова                    0                 1      0.000000
#          гражданский брак                  0                 8      0.000000
#          женат / замужем                   3                29     10.344828
#          не женат / не замужем             1                 2     50.000000
# 5        гражданский брак                  0                 2      0.000000
#          женат / замужем                   0                 7      0.000000

# %% [markdown]
# Проверим как разные цели кредита влияют на его возврат в срок?

# %%
df_goal = df.pivot_table(index = ['purpose'], values = 'debt', aggfunc = [sum, 'count'])
#df_child = df.groupby(['children',]).agg({'debt':'sum','children':'count'})
df_goal['%_total_debt'] = (df_goal['sum','debt']/df_goal['count','debt'])
df_goal.columns = ['Кол-во невозвратов','Кол-во заемщиков','% невозврата']
df_goal.style.format({'% невозврата':'{:.2%}'})
#print(df_child)
# Out:
# <style  type="text/css" >
# </style><table id="T_b5b3386e_8a40_11ec_b48a_02420a390fde" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Кол-во невозвратов</th>        <th class="col_heading level0 col1" >Кол-во заемщиков</th>        <th class="col_heading level0 col2" >% невозврата</th>    </tr>    <tr>        <th class="index_name level0" >purpose</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5b3386e_8a40_11ec_b48a_02420a390fdelevel0_row0" class="row_heading level0 row0" >автомобиль</th>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow0_col0" class="data row0 col0" >403</td>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow0_col1" class="data row0 col1" >4306</td>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow0_col2" class="data row0 col2" >9.36%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b3386e_8a40_11ec_b48a_02420a390fdelevel0_row1" class="row_heading level0 row1" >жилье</th>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow1_col0" class="data row1 col0" >308</td>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow1_col1" class="data row1 col1" >4460</td>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow1_col2" class="data row1 col2" >6.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b3386e_8a40_11ec_b48a_02420a390fdelevel0_row2" class="row_heading level0 row2" >недвижимость</th>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow2_col0" class="data row2 col0" >474</td>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow2_col1" class="data row2 col1" >6351</td>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow2_col2" class="data row2 col2" >7.46%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b3386e_8a40_11ec_b48a_02420a390fdelevel0_row3" class="row_heading level0 row3" >образование</th>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow3_col0" class="data row3 col0" >370</td>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow3_col1" class="data row3 col1" >4013</td>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow3_col2" class="data row3 col2" >9.22%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b3386e_8a40_11ec_b48a_02420a390fdelevel0_row4" class="row_heading level0 row4" >свадьба</th>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow4_col0" class="data row4 col0" >186</td>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow4_col1" class="data row4 col1" >2324</td>
#                         <td id="T_b5b3386e_8a40_11ec_b48a_02420a390fderow4_col2" class="data row4 col2" >8.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Вывод**

# %% [markdown]
# Сводные таблицы сделаны данные представлены в удобном для чтения виде

# %% [markdown]
# ## Шаг 3. Ответьте на вопросы

# %% [markdown]
# - Есть ли зависимость между наличием детей и возвратом кредита в срок?

# %%
df_child = df.pivot_table(index = ['children'], values = 'debt', aggfunc = [sum, 'count'])
df_child['%_total_debt'] = (df_child ['sum','debt']/df_child ['count','debt'])
df_child.columns = ['Кол-во невозвратов','Кол-во заемщиков','% невозврата']
df_child.style.format({'% невозврата':'{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_b5b69acc_8a40_11ec_b48a_02420a390fde" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Кол-во невозвратов</th>        <th class="col_heading level0 col1" >Кол-во заемщиков</th>        <th class="col_heading level0 col2" >% невозврата</th>    </tr>    <tr>        <th class="index_name level0" >children</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5b69acc_8a40_11ec_b48a_02420a390fdelevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow0_col0" class="data row0 col0" >1063</td>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow0_col1" class="data row0 col1" >14091</td>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow0_col2" class="data row0 col2" >7.54%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b69acc_8a40_11ec_b48a_02420a390fdelevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow1_col0" class="data row1 col0" >445</td>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow1_col1" class="data row1 col1" >4855</td>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow1_col2" class="data row1 col2" >9.17%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b69acc_8a40_11ec_b48a_02420a390fdelevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow2_col0" class="data row2 col0" >202</td>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow2_col1" class="data row2 col1" >2128</td>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow2_col2" class="data row2 col2" >9.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b69acc_8a40_11ec_b48a_02420a390fdelevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow3_col0" class="data row3 col0" >27</td>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow3_col1" class="data row3 col1" >330</td>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow3_col2" class="data row3 col2" >8.18%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b69acc_8a40_11ec_b48a_02420a390fdelevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow4_col0" class="data row4 col0" >4</td>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow4_col1" class="data row4 col1" >41</td>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow4_col2" class="data row4 col2" >9.76%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b69acc_8a40_11ec_b48a_02420a390fdelevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow5_col1" class="data row5 col1" >9</td>
#                         <td id="T_b5b69acc_8a40_11ec_b48a_02420a390fderow5_col2" class="data row5 col2" >0.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Вывод**

# %% [markdown]
# Условная зависимость присутствует, люди без детей чаще погашают кредиты в срок, но разница очень мала, в следствие чего присутствует вероятность статистической погрешности

# %% [markdown]
# - Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
df_family = df.groupby('family_status').agg({'debt':'sum', 'family_status':'count'})
df_family['%_total_debt'] = (df_family['debt']/df_family['family_status'])
df_family.columns = ['Кол-во невозвратов','Кол-во заемщиков','% невозврата']
df_family.style.format({'% невозврата':'{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fde" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Кол-во невозвратов</th>        <th class="col_heading level0 col1" >Кол-во заемщиков</th>        <th class="col_heading level0 col2" >% невозврата</th>    </tr>    <tr>        <th class="index_name level0" >family_status</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fdelevel0_row0" class="row_heading level0 row0" >в разводе</th>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow0_col0" class="data row0 col0" >85</td>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow0_col1" class="data row0 col1" >1195</td>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow0_col2" class="data row0 col2" >7.11%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fdelevel0_row1" class="row_heading level0 row1" >вдовец / вдова</th>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow1_col0" class="data row1 col0" >63</td>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow1_col1" class="data row1 col1" >959</td>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow1_col2" class="data row1 col2" >6.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fdelevel0_row2" class="row_heading level0 row2" >гражданский брак</th>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow2_col0" class="data row2 col0" >388</td>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow2_col1" class="data row2 col1" >4151</td>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow2_col2" class="data row2 col2" >9.35%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fdelevel0_row3" class="row_heading level0 row3" >женат / замужем</th>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow3_col0" class="data row3 col0" >931</td>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow3_col1" class="data row3 col1" >12339</td>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow3_col2" class="data row3 col2" >7.55%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fdelevel0_row4" class="row_heading level0 row4" >не женат / не замужем</th>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow4_col0" class="data row4 col0" >274</td>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow4_col1" class="data row4 col1" >2810</td>
#                         <td id="T_b5b8f1e6_8a40_11ec_b48a_02420a390fderow4_col2" class="data row4 col2" >9.75%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Вывод**

# %% [markdown]
# Самые низкие показатели у показателей 'в разводе' и 'вдовец / вдова'  можно предположить, что погашение кредитов зависит в том числе от наличия пары в семье.

# %% [markdown]
# - Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %% [markdown]
# сгруппируем людей по уровню доходов в 4 группы

# %%
df['total_income'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    107623.00
# 0.50    142594.00
# 0.75    195820.25
# Name: total_income, dtype: float64

# %%
def income_status(total_income):
    if total_income <= 88946.5:
            return 'Низкий уровень дохода'
    if total_income <= 135716.0:
            return 'Средний уровень дохода'
    if total_income < 195751.5:
            return 'Высокий уровень дохода'
    return 'Сверхвысокий уровень дохода'

# %%
df['income_status'] = df['total_income'].apply(income_status)

# %%
df.head()
# Out:
#    children  dob_years education  education_id     family_status  \
# 0         1         42    высшее             0   женат / замужем
# 1         1         36   среднее             1   женат / замужем
# 2         0         33   среднее             1   женат / замужем
# 3         3         32   среднее             1   женат / замужем
# 4         0         53   среднее             1  гражданский брак
#
#    family_status_id gender income_type  debt  total_income      purpose  \
# 0                 0      F   сотрудник     0        253875        жилье
# 1                 0      F   сотрудник     0        112080   автомобиль
# 2                 0      M   сотрудник     0        145885        жилье
# 3                 0      M   сотрудник     0        267628  образование
# 4                 1      F   пенсионер     0        158616      свадьба
#
#    years_employed                income_status
# 0              23  Сверхвысокий уровень дохода
# 1              11       Средний уровень дохода
# 2              15       Высокий уровень дохода
# 3              11  Сверхвысокий уровень дохода
# 4               6       Высокий уровень дохода

# %%
total_income_set = df.groupby('income_status')['debt'].sum() / \
      df.groupby('income_status')['debt'].count() * 100

# %%
total_income_set.sort_values()
# Out:
# income_status
# Сверхвысокий уровень дохода    7.133544
# Низкий уровень дохода          7.666256
# Средний уровень дохода         8.515815
# Высокий уровень дохода         8.739235
# Name: debt, dtype: float64

# %%
total_income_pivot = df.pivot_table(index=['income_status'], columns=['debt'], values='education_id', aggfunc='count')
total_income_pivot['ratio'] = total_income_pivot[1] / total_income_pivot[0] * 100
total_income_pivot
# Out:
# debt                            0    1     ratio
# income_status
# Высокий уровень дохода       6464  619  9.576114
# Низкий уровень дохода        2999  249  8.302768
# Сверхвысокий уровень дохода  4986  383  7.681508
# Средний уровень дохода       5264  490  9.308511

# %%
# Проверим количество людей в каждой из групп
df['income_status'].value_counts(normalize = True)
# Out:
# Высокий уровень дохода         0.330148
# Средний уровень дохода         0.268202
# Сверхвысокий уровень дохода    0.250256
# Низкий уровень дохода          0.151394
# Name: income_status, dtype: float64

# %% [markdown]
# **Вывод**

# %% [markdown]
# Самые плохие показатели у групп со средним и высоким доходом,
# С количеством человек в каждой из групп — порядок.

# %% [markdown]
# - Как разные цели кредита влияют на его возврат в срок?

# %%
df_goal = df.pivot_table(index = ['purpose'], values = 'debt', aggfunc = [sum, 'count'])
#df_child = df.groupby(['children',]).agg({'debt':'sum','children':'count'})
df_goal['%_total_debt'] = (df_goal['sum','debt']/df_goal['count','debt'])
df_goal.columns = ['Кол-во невозвратов','Кол-во заемщиков','% невозврата']
df_goal.style.format({'% невозврата':'{:.2%}'})
#print(df_child)
# Out:
# <style  type="text/css" >
# </style><table id="T_b5eb52d0_8a40_11ec_b48a_02420a390fde" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Кол-во невозвратов</th>        <th class="col_heading level0 col1" >Кол-во заемщиков</th>        <th class="col_heading level0 col2" >% невозврата</th>    </tr>    <tr>        <th class="index_name level0" >purpose</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5eb52d0_8a40_11ec_b48a_02420a390fdelevel0_row0" class="row_heading level0 row0" >автомобиль</th>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow0_col0" class="data row0 col0" >403</td>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow0_col1" class="data row0 col1" >4306</td>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow0_col2" class="data row0 col2" >9.36%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5eb52d0_8a40_11ec_b48a_02420a390fdelevel0_row1" class="row_heading level0 row1" >жилье</th>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow1_col0" class="data row1 col0" >308</td>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow1_col1" class="data row1 col1" >4460</td>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow1_col2" class="data row1 col2" >6.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5eb52d0_8a40_11ec_b48a_02420a390fdelevel0_row2" class="row_heading level0 row2" >недвижимость</th>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow2_col0" class="data row2 col0" >474</td>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow2_col1" class="data row2 col1" >6351</td>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow2_col2" class="data row2 col2" >7.46%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5eb52d0_8a40_11ec_b48a_02420a390fdelevel0_row3" class="row_heading level0 row3" >образование</th>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow3_col0" class="data row3 col0" >370</td>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow3_col1" class="data row3 col1" >4013</td>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow3_col2" class="data row3 col2" >9.22%</td>
#             </tr>
#             <tr>
#                         <th id="T_b5eb52d0_8a40_11ec_b48a_02420a390fdelevel0_row4" class="row_heading level0 row4" >свадьба</th>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow4_col0" class="data row4 col0" >186</td>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow4_col1" class="data row4 col1" >2324</td>
#                         <td id="T_b5eb52d0_8a40_11ec_b48a_02420a390fderow4_col2" class="data row4 col2" >8.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Вывод**

# %% [markdown]
# Хуже всего выглядят категории: образование и автомобиль.

# %% [markdown]
# ## Шаг 4. Общий вывод

# %% [markdown]
# Присутствует зависимости между целями кредита, семейным положением, уровнем дохода и количеством детей в семье. Нельзя сказать, что они кардинально отличаются, но они   могут оказать существенное влияние на кредитный портфель банка.

# %% [markdown]
# # Рекомендации для банка
# - Продумать сценарий, когда отличается дата или время заявки, а уникальный идентификатор пользователя один и тот же,
#   иначе фактически дубли будут, но метод duplicated() их не найдет.
# - Уделить внимание правилам валидации на сервере, чтобы больше не сталкиваться с проблемой дублей.
# - Блокировать отправку заявок с заведомо некорректными значениями, которые могут быть важны для анализа, например,
#   с отрицательным количеством детей.
# - Считать стаж работы в годах, пользователи чаще всего не знают свой стаж в днях.
